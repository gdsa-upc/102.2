# %% [markdown]
# # Jupyter Notebook Sessio 6_2 Rank improved

# %%
import os
os.chdir('C:\Users\Gerard\Documents\Universidad\TercerCurso\GDSA\Proyecto\egara_view\codigo')

# %% [markdown]
# #### Importem les funcions necessaries

# %%
from get_params import get_params
from build_database import build_database
from get_features import get_features
from rank import rank
from eval_rankings import eval_rankings
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Construim la base de dades de train i validacio

# %%
params=get_params()
params['split']='train'
build_database(params)
params['split']='val'
build_database(params)

# %% [markdown]
# #### Obtenim les caracteristiques i realitzem el ranking basat en les distancies euclideas

# %% [markdown]
# La nostra funcio get_features inclou totes les creades per aquesta sessio: get_local_features,
# train_codebook, get_assignments i build_bow

# %%
get_features(params)
rank(params)
# Out:
# numero de paraules1000

# %% [markdown]
# #### Mostrem una imatge de validacio amb les 10 primeres que mes s'asemblen segons el nostre ranking

# %%
#Mostrem el ranking de les 10 imatges que mes s'asemblen segons el sistema desenvolupat 
files = open((os.path.join(params['root'],params['database'],'val','result','2807-7096-24202'+'.txt')),'r')
i=0
print("Imatge a analitzar en el rank")
os.chdir('C:\Users\Gerard\Documents\Universidad\TercerCurso\GDSA\Proyecto\egara_view\TerrassaBuildings900\\val\images')
img=mpimg.imread('2807-7096-24202.jpg')
plt.imshow(img),plt.show()
os.chdir('C:\Users\Gerard\Documents\Universidad\TercerCurso\GDSA\Proyecto\egara_view\TerrassaBuildings900\\train\images')
print("Ara mostrem el ranking")
for i in range(0,10):
    img2=mpimg.imread(files.readline().replace('\n','')+'.jpg')
    plt.imshow(img2),plt.show()
    i=i+1
files.close()
# Out:
# Imatge a analitzar en el rank
# Ara mostrem el ranking

# %% [markdown]
# #### Calculem les Average Precission i la Mean Average Precission

# %%
ap_list=eval_rankings(params)
print "-Llista d'Average Precission: "+"\n" "%s" % ap_list
print "\n"+"-Mean Average Precission: "+"\n" "%s" % np.mean(ap_list)
# Out:
# -Llista d'Average Precission:
# [0.270557871087975, 0.47079422177976193, 0.387906206626069, 0.10909893076408592, 0.45065766806051455, 0.14280702308688004, 0.2684580707282675, 0.06669684807027611, 0.34116256266957623, 0.06112563466940964, 0.549313763417736, 0.591676659436547, 0.11853674620225103, 0.3723333673440474, 0.4957673179095138, 0.2003222075944185, 0.21567680599488678, 0.3518126741378906, 0.5051835040205434, 0.39895252429905265, 0.3898775158286332, 0.20953899170151424, 0.0977039079344679, 0.3800368999579302, 0.47362696944075944, 0.2995408474232015, 0.23875953447547119, 0.2699675207935493, 0.8690890911945397, 0.11353754579191438, 0.544138465402519, 0.093120322336579, 0.5335181268308374, 0.10719569208464197, 0.1245064845871524, 0.5421188035006904, 0.34288391083592146, 0.316820257812574, 0.2072799695594604, 0.11221774038730267, 0.07316143234209503, 0.13159122469266646, 0.31423428919112445, 0.34877318202477203, 0.22163995735581413, 0.35307363123414076, 0.15986354054847665, 0.1421300210377691, 0.12295737774571876, 0.38218391002558616, 0.09814164839643678, 0.25269087381081123, 0.3974405719567857, 0.11402463825675639, 0.0447266844896555, 0.42153943961040996, 0.13660763803610096, 0.17210071032123367, 0.22949772067152466, 0.3060786963290908, 0.10827319335812888, 0.133045587975891, 0.3320317400538063, 0.2768347545663522, 0.10008162128279226, 0.29555707113949875, 0.11432313633687263, 0.1437672915669804, 0.41552474835014885, 0.054549152390443216, 0.5287505383446764, 0.3232619814409714, 0.27141129330311065, 0.35530244417599405, 0.41554114658256047, 0.19295454499822445, 0.14423221128602537, 0.7590049663976426, 0.42394007230835884, 0.13137998191830275, 0.7191888797571029, 0.5221734937700028, 0.4204825236106082, 0.11856546021204518, 0.4424501000615438, 0.17668227785763563, 0.11919372843092665, 0.5905145859792351, 0.20708692725946398, 0.0803612780962212, 0.20037631044871546, 0.5098355040699726, 0.6492924642584076, 0.5517484204501582, 0.05654496889438005, 0.9100143885225728, 0.2799927806798501, 0.5635147350654853, 0.12293270313732087, 0.7734834735010527, 0.08494683733051213, 0.04774304616705364, 0.5910173831118857, 0.07772687944722358, 0.116361624439168, 0.2690087820146626, 0.38852831813942396, 0.0887411405275531, 0.3285252184103705, 0.23418965992352622, 0.141737831140717, 0.07661770233935504, 0.32672137050352473, 0.42469324289984167, 0.1158793728609028, 0.04926367506594803, 0.13070360324757263, 0.1398452900514159, 0.32115987661755957, 0.07366291159396925]
#
# -Mean Average Precission:
# 0.288483772013
