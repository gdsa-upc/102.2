# %% [markdown]
# # Jupyter Notebook Sessio 7 Rank improved

# %%
import os
os.chdir('C:\Users\Carles\Desktop\Pruebas Python')

# %% [markdown]
# #### Importem les funcions necessaries

# %%
from get_params import get_params
from build_database import build_database
from get_features import get_features
from rank import rank
from eval_rankings import eval_rankings
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Construim la base de dades de train i validacio

# %%
params=get_params()
params['split']='train'
build_database(params)
params['split']='val'
build_database(params)

# %% [markdown]
# #### Obtenim les caracteristiques i realitzem el ranking basat en les distancies euclideas

# %% [markdown]
# La nostra funcio get_features inclou totes les creades per aquesta sessio: get_local_features,
# train_codebook, get_assignments i build_bow

# %% [markdown]
# Fem un resize de 250 per aquesta Notebook en comptes del que utilitzem normalment (800) per a que el codi tardi menys en executar-se ja que com volem treure a mes una grafica amb diferents valors del Codebook necessitarem executar-lo mes d'una vegada

# %% [markdown]
# Tambe en aquesta Notebook hem modificat la funcio get_features de forma que li podem passar el Codebook size i executar-lo amb diferents valors, pero aquesta modificacio la fem exclusivament per aquesta Notebook

# %%
lista_paraules=list()
ap=list()
mAP=list()
lista_paraules=[100, 1000, 2000, 4000, 8000, 10000]
params['max_size'] = 250
for paraules in lista_paraules:
    get_features(params,paraules)
    #Calcul del ranking
    rank(params)
    #Evaluacio del ranking
    ap_list=eval_rankings(params)
    ap.append(ap_list)
    mAP.append(np.mean(ap_list))

# %% [markdown]
# Utilitzem diferents valors pel Codebook: 100, 1000, 2000, 4000, 8000 i 10000

# %% [markdown]
# #### Mostrem una imatge de validacio amb les 10 primeres que mes s'asemblen segons el nostre ranking

# %%
files = open((os.path.join(params['root'],params['database'],'val','result','2807-7096-24202'+'.txt')),'r')
i=0
print("Imatge a analitzar en el rank")
os.chdir('C:\Users\Carles\Desktop\Pruebas Python\TerrassaBuildings900\\val\images')
img=mpimg.imread('2807-7096-24202.jpg')
plt.imshow(img),plt.show()
os.chdir('C:\Users\Carles\Desktop\Pruebas Python\TerrassaBuildings900\\train\images')
print("Ara mostrem el ranking")
for i in range(0,10):
    img2=mpimg.imread(files.readline().replace('\n','')+'.jpg')
    plt.imshow(img2),plt.show()
    i=i+1
files.close()
# Out:
# Imatge a analitzar en el rank
# Ara mostrem el ranking

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ind = range(1,7)  
width = 0.35   # Grossor de les barres

# Barres
opacity = 0.7
plt.bar(ind, mAP, width, alpha=opacity,color='red')

# Axes and labels
ax.set_xlim(width,len(ind)+1)
ax.set_ylim(0,0.4)
xTickMarks = [str(lista_paraules[i]) for i in range(0,6)]
ax.set_xticks(([i+width for i in ind]))
xtickNames = ax.set_xticklabels(xTickMarks)
plt.setp(xtickNames, rotation=45, fontsize=10)
plt.xlabel('Codebook size')
plt.ylabel('mAP')
plt.title('Retrieval experiment for different codebook sizes')
plt.show()

valores = [[lista_paraules[0], mAP[0]],[lista_paraules[1], mAP[1]],[lista_paraules[2], mAP[2]],[lista_paraules[3], mAP[3]],[lista_paraules[4], mAP[4]],[lista_paraules[5], mAP[5]]]
etiquetas_col = (u'Codebook size', u'mAP')
plt.table(cellText=valores, colLabels = etiquetas_col, colWidths = [0.3]*len(lista_paraules), loc='upper center')

# %% [markdown]
# El millor resultat ens ha donat amb el Codebook amb 4000 clusters:

# %%
print "-Llista d'Average Precission: "+"\n" "%s" % ap[3]
print "\n"+"-Mean Average Precission: "+"\n" "%s" % mAP[3]
# Out:
# -Llista d'Average Precission:
# [0.15356119675466262, 0.4277296626324979, 0.17497240239095252, 0.2946724902766202, 0.06072217915290018, 0.269396186207381, 0.08589086486641259, 0.35797340508283865, 0.41697373365130813, 0.16882413182995099, 0.0680797741219617, 0.3574723886419969, 0.21751741141404238, 0.06229245531063286, 0.5395756562767485, 0.8327341717291235, 0.076495636517051, 0.23348476925640807, 0.2903040580249001, 0.6677536273436294, 0.06005413176350924, 0.3092791685104002, 0.2658675715777855, 0.20102072454538805, 0.2902779929136472, 0.43669776272782523, 0.4090406808757549, 0.33284429317496994, 0.4374430970872199, 0.15284500134069373, 0.13447270801416425, 0.24374145473029962, 0.0921810906364819, 0.2813715035254675, 0.5705692403887364, 0.2784065746401043, 0.2939133253369425, 0.32589265879795687, 0.07199539294442259, 0.31986089819582975, 0.10117429813925705, 0.8622865614153341, 0.07921867760155418, 0.39255740882092477, 0.3697096587251214, 0.31470483903504454, 0.049869528266805095, 0.2044509029951618, 0.10048563834263055, 0.5161343703133389, 0.10476143611278216, 0.44079712093587053, 0.40580408223764713, 0.4014102594437461, 0.3961265866701458, 0.23951777697362156, 0.3749618819529627, 0.18281390452563326, 0.42973031436094167, 0.4439621286213575, 0.3935511174866426, 0.0853235952560412, 0.13402360133189054, 0.04971534931187848, 0.4595377066631241, 0.10080969740796585, 0.16646636800838166, 0.23601561981747732, 0.7384578329719025, 0.4222137467442156, 0.40099350142580625, 0.33550974176630094, 0.3735532260535374, 0.4272417409192042, 0.09211197078796085, 0.10728498507924406, 0.11441462527645012, 0.41614147399221, 0.11897802876537276, 0.22350341418807193, 0.30551540941289707, 0.14159439222149436, 0.478031892661548, 0.27453180762659585, 0.3568967330753264, 0.1039132173136252, 0.09541189447579597, 0.2714808604146631, 0.06876369858626301, 0.4223067005587626, 0.24644591754615885, 0.0843784972241064, 0.38120800057078463, 0.5164533529433919, 0.0692248449206821, 0.4809397354621393, 0.26161702349077826, 0.0636925077908109, 0.2711722094810697, 0.16586209906150992, 0.10769003578912731, 0.323741387772967, 0.3244000622324102, 0.16767315518480796, 0.1337391470925224, 0.04121199333314593, 0.43851781981319937, 0.12353949496429222, 0.3315242894666027, 0.3911287937118474, 0.15437382478184772, 0.808796090145183, 0.22753135667374347, 0.2557814728018498, 0.27765211844054805, 0.12227331288873276, 0.09400882055450119, 0.11443783609669426, 0.8041717093614439, 0.46385955186840905, 0.445953713045032, 0.5148079461413474, 0.07672629293802812, 0.2773035323140187, 0.7795497616669403, 0.4432753543884227, 0.20950286843529103, 0.6303314013655679, 0.5043338023959771, 0.30766968652565674, 0.3754183291572204, 0.12105910417848958, 0.08156031583424124, 0.16981899657926303, 0.5033936179750509, 0.16968419953020264, 0.10851377940997324, 0.24794338672319935, 0.6319464177386176, 0.4616436957682484, 0.5512658752376339, 0.7840538860739094, 0.10314661962392706, 0.8874983537274558, 0.09511538086666363, 0.401668742739863, 0.12476766197065146, 0.7922097773743559, 0.18072997264688323, 0.06022516450096657, 0.3521785558769551, 0.4536645983345888, 0.13982884611920482, 0.07183442460759118, 0.4065689876979123, 0.34446128382138014, 0.31465415453084744, 0.3066407744997373, 0.3806174803871506, 0.07324326174980644, 0.4324269897374733, 0.28194777479619026, 0.2763749558716313, 0.09640707353929377, 0.41109511484186445, 0.17999285520582134, 0.14683981042563846, 0.045316159879257724, 0.3551446586030075, 0.49563411262488766, 0.2833998890253081, 0.38547508127103236, 0.44315348917631886, 0.06038118321666754, 0.05657081558344463, 0.11972607362230114, 0.2405105922702683, 0.313598813990353, 0.40762617278336294, 0.08717566022575142, 1.0]
#
# -Mean Average Precission:
# 0.297456500226
