# %%
import os
os.chdir('C:\Users\Gerard\Documents\Universidad\TercerCurso\GDSA\Proyecto\Codigo')

# %%
#Carreguem totes les funcions
from get_params import get_params
from build_database import build_database
from get_features import get_features
from rank import rank
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#Construim la base de dades 
params=get_params()
params['split']='val'
build_database(params)
params['split']='train'
build_database(params)

# %%
#Obtenim les caracteristiques i realitzem el ranking basat en les distancies euclideas
#get_features(params)
rank(params)
#
# Out:
# C:\Users\Gerard\AppData\Local\Enthought\Canopy\User\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\Gerard\AppData\Local\Enthought\Canopy\User\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# ...

# %%
#Mostrem el ranking de les 10 imatges que mes s'asemblen segons el sistema desenvolupat 
files = open((os.path.join(params['root'],params['database'],'val','result','2807-7096-24202'+'.txt')),'r')
i=0
os.chdir('C:\Users\Gerard\Documents\Universidad\TercerCurso\GDSA\Proyecto\Codigo\TerrassaBuildings900\\val\images')
print("Imatge a analitzar en el rank)
img = cv2.imread('2807-7096-24202.jpg',0) 
plt.imshow(img)
os.chdir('C:\Users\Gerard\Documents\Universidad\TercerCurso\GDSA\Proyecto\Codigo\TerrassaBuildings900\\train\images')
print("Ara mostrem el ranking")
   for line in files:
   if i<=10:
        img2=cv2.imread(line.replace('\n','')+'.jpg',0)
        plt.imshow(img2),plt.show()
        # cv2.imshow('imagen'+line,img2)
        i=i+1
